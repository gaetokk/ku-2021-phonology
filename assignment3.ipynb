# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/assignment3
! ls
# Out:
# /content/gdrive/MyDrive/assignment3
# 01_lec_python_basic.ipynb  assignment3.ipynb  yourgoodpants_formants.csv
# 02_pyplot.ipynb		   yourgoodpants.csv  yourgoodpants_intensity.csv

# %%
df = pd.read_csv('yourgoodpants.csv', sep=',')
df.loc[df.Time_s == "--undefined--", "Time_s"] = None
df.loc[df.F0_Hz == "--undefined--", "F0_Hz"] = None
print(df)
# Out:
#       Word    Time_s       F0_Hz  ...  Unnamed: 6  Unnamed: 7  Unnamed: 8
# 0     your      None        None  ...         NaN         NaN         NaN
# 1     your      None        None  ...         NaN         NaN         NaN
# 2     your      None        None  ...         NaN         NaN         NaN
# 3     your      None        None  ...         NaN         NaN         NaN
# 4     your  1.078274  271.698586  ...         NaN         NaN         NaN
# ..     ...       ...         ...  ...         ...         ...         ...
# 423  great      None        None  ...         NaN         NaN         NaN
# 424  great      None        None  ...         NaN         NaN         NaN
# 425  great      None        None  ...         NaN         NaN         NaN
# 426  great      None        None  ...         NaN         NaN         NaN
# 427  great      None        None  ...         NaN         NaN         NaN
#
# [428 rows x 9 columns]

# %%
time = df.Time_s
f0 = df.F0_Hz

plt.plot(time, f0, 'ro', label='pitch(Hz)')
plt.xlabel('tiem(sec)')
plt.ylabel('pitch(Hz)')
plt.legend(loc='best', ncol=2, fontsize=14, frameon=True, shadow=True)
plt.show()

# %%
df = pd.read_csv('yourgoodpants_intensity.csv', sep=',')
df.loc[df.Time_s == "--undefined--", "Time_s"] = None
df.loc[df.Intensity_dB == "--undefined--", "Intensity_dB"] = None
print(df)
# Out:
#       Word    Time_s  Intensity_dB  ...  Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0     your  1.056033     37.744703  ...         NaN         NaN         NaN
# 1     your  1.061550     41.883338  ...         NaN         NaN         NaN
# 2     your  1.067067     46.160764  ...         NaN         NaN         NaN
# 3     your  1.072584     52.307281  ...         NaN         NaN         NaN
# 4     your  1.078101     57.321823  ...         NaN         NaN         NaN
# ..     ...       ...           ...  ...         ...         ...         ...
# 396  great  3.240860     46.892266  ...         NaN         NaN         NaN
# 397  great  3.246377     48.182938  ...         NaN         NaN         NaN
# 398  great  3.251895     48.783079  ...         NaN         NaN         NaN
# 399  great  3.257412     49.596161  ...         NaN         NaN         NaN
# 400  great  3.262929     50.207202  ...         NaN         NaN         NaN
#
# [401 rows x 8 columns]

# %%
time = df.Time_s
intensity = df.Intensity_dB

plt.plot(time, intensity, 'ro', label='intensity(dB)')
plt.xlabel('tiem(sec)')
plt.ylabel('intensity(dB)')
plt.legend(loc='best', ncol=2, fontsize=14, frameon=True, shadow=True)
plt.show()

# %%
df = pd.read_csv('yourgoodpants_formants.csv', sep=',')
df.loc[df.Time_s == "--undefined--", "Time_s"] = None
df.loc[df.F1_Hz == "--undefined--", "F1_Hz"] = None
df.loc[df.F2_Hz == "--undefined--", "F2_Hz"] = None
df.loc[df.F3_Hz == "--undefined--", "F3_Hz"] = None
df.loc[df.F4_Hz == "--undefined--", "F4_Hz"] = None
print(df)
# Out:
#       Word    Time_s        F1_Hz  ...        F3_Hz        F4_Hz Unnamed: 6
# 0     your  1.059308  1317.291416  ...  3933.683540  5280.838853        NaN
# 1     your  1.065558   263.147429  ...  2805.297592  3804.921148        NaN
# 2     your  1.071808   292.894241  ...  3657.970936  4040.258846        NaN
# 3     your  1.078058   292.353978  ...  3597.382242  4067.530399        NaN
# 4     your  1.084308   293.909466  ...  3601.229632  4092.344624        NaN
# ..     ...       ...          ...  ...          ...          ...        ...
# 349  great  3.240558   994.662583  ...  3576.650573  4454.764198        NaN
# 350  great  3.246808   949.191509  ...  3294.618435  4540.045793        NaN
# 351  great  3.253058   876.124713  ...  3271.585831  4608.051187        NaN
# 352  great  3.259308   707.482779  ...  3186.368747  4507.277921        NaN
# 353  great  3.265558   519.531473  ...  3196.574234  4534.970791        NaN
#
# [354 rows x 7 columns]

# %%
time = df.Time_s
f1 = df.F1_Hz
f2 = df.F2_Hz
f3 = df.F3_Hz
f4 = df.F4_Hz

plt.plot(time, f1, 'ro', label='F1')
plt.plot(time, f2, 'bo', label='F2')
plt.plot(time, f3, 'go', label='F3')
plt.plot(time, f4, 'yo', label='F4')
plt.xlabel('time(sec)')
plt.ylabel('frequency(Hz)')
plt.legend(loc='best', ncol=2, fontsize=14, frameon=True, shadow=True)
plt.show()
